# %% [markdown]
# <a href="https://colab.research.google.com/github/jcho49614/projects/blob/main/modeltrain6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim #optimizer
import torch.nn.functional as F
from torchvision import datasets, transforms #datasets, transforms
from torch.utils.data import DataLoader as DL #DataLoader wrapping it around.
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
# !pip install nvidia-ml-py3
# Out:
# Requirement already satisfied: nvidia-ml-py3 in /usr/local/lib/python3.11/dist-packages (7.352.0)

# %%
from pynvml import *

def show_cuda_usage():
    nvmlInit()
    handle = nvmlDeviceGetHandleByIndex(0)  # GPU 0

    mem_info = nvmlDeviceGetMemoryInfo(handle)
    util_info = nvmlDeviceGetUtilizationRates(handle)

    print(f"GPU Memory Used: {mem_info.used / 1024**2:.2f} MB")
    print(f"GPU Memory Total: {mem_info.total / 1024**2:.2f} MB")
    print(f"GPU Utilization: {util_info.gpu}%")
    print(f"Memory Utilization: {util_info.memory}%")

    nvmlShutdown()

# %%
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
  print("Device Name:", torch.cuda.get_device_name(0))
  print("CUDA Version:", torch.version.cuda)
  print("Torch Version:", torch.__version__)
# Out:
# CUDA Available: True
# Device Name: Tesla T4
# CUDA Version: 12.4
# Torch Version: 2.6.0+cu124

# %%
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # mean and std tuples
])

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

# %%
#using CIFAR100!
trainset = torchvision.datasets.CIFAR100(
    root = './data',
    train = True,
    download = True,
    transform=transform_train
)
testset = torchvision.datasets.CIFAR100(
    root = './data',
    train = False,
    download = True,
    transform=transform
)

# %%
trainloader = DL(trainset, batch_size = 15000, shuffle=True, num_workers=20, pin_memory=True)
testloader = DL(testset, batch_size = 15000, shuffle= False, num_workers = 20, pin_memory=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 20 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# class CNNMODEL(nn.Module):
#   def __init__(self): #self refers to the instance itself!
#     super(CNNMODEL, self).__init__()
#     self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
#     self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
#     self.conv3 = nn.Conv2d(64, 128, 3, padding = 1)
#     self.pool = nn.MaxPool2d(2,2)
#     self.fc1 = nn.Linear(128*4*4, 128) #flatten to 128
#     self.fc2 = nn.Linear(128,100) #classify to 100 classes.

#   def forward(self, x): #x is just a newly created
#     x = self.pool(F.relu(self.conv1(x)))
#     x = self.pool(F.relu(self.conv2(x)))
#     x = self.pool(F.relu(self.conv3(x)))
#     x = x.view(x.size(0), -1)
#     x = F.relu(self.fc1(x))
#     x = self.fc2(x)
#     return x
#this is one way of writing a cnn module. compact but quite hard to understand.

# %%
class CNNMODEL(nn.Module):
  def __init__(self):
    super(CNNMODEL, self).__init__() #establish the initialization of nn.Module
    self.convolution1 = nn.Sequential(
        nn.Conv2d(3, 16, kernel_size=3, padding=1), #padding keeps the size the same -- floor(kernel_size / 2) is best for padding
        nn.ReLU(), #non-linearity
        nn.MaxPool2d(2,2) #divide length, width by half
    )

    self.convolution2 = nn.Sequential(
        nn.Conv2d(16, 32, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2)
    )

    self.convolution3 = nn.Sequential(
        nn.Conv2d(32, 64, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2)
    )

    self.convolution4 = nn.Sequential(
        nn.Conv2d(64, 128, kernel_size = 3, padding=1),
        nn.ReLU(),
        nn.MaxPool2d(2,2)
    )

    self.convolution5 = nn.Sequential(
        nn.Conv2d(128, 256, kernel_size = 3, padding = 1),
        nn.ReLU(),
        nn.MaxPool2d(2,2)
    )

    self.fullyconnected = nn.Sequential(
        nn.Linear(256, 128),
        nn.ReLU()
    )

    self.fc2 = nn.Sequential(
        nn.Linear(128,100)
    )

    self.dropout = nn.Dropout(p=0.5)

# nn.ReLU() needs to be explicitly stated. F.relu() can simply just be mentioned. nn.ReLU() is good for nn.Sequential stuff, F.relu() is good for simply just mentioning it.
#F.relu() is a function, nn.ReLU() is a module, part of nn.Module.

  def forward(self, x):
    x = self.convolution1(x)
    x = self.convolution2(x)
    x = self.convolution3(x)
    x = self.convolution4(x)
    x = self.convolution5(x)
    x = x.view(x.size(0), -1)
    x = self.fullyconnected(x)
    x = self.dropout(x)
    x = self.fc2(x) #last layer does not have a ReLU because it removes negative values to 0.
    return x

# %%
model = CNNMODEL().to(device) #send it to device. make reference called "model".

# %%
criterion = nn.CrossEntropyLoss() #find criterion
optimizer = optim.Adam(model.parameters(), lr=0.001) #use the model parameters, and the learning rate is 0.00001 so it would converge well.
scheduler = ReduceLROnPlateau(
  optimizer,
  mode='min',
  factor=0.01,
  patience=5,
  verbose=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
num_epochs = 200
for epoch in range(num_epochs):
  print(f"Epoch {epoch + 1} training....", end='')
  model.train() #turn on training mode
  running_loss = 0.0
  for data, labels in trainloader:
    data = data.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()
    output = model(data) #this refers to x! "data" goes through conv1, relu, pooling, flattening, etc etc.
    loss=criterion(output,labels) #criterion calculates the loss!
    loss.backward() #feed back to model to adjust to optimizer
    optimizer.step() #go forward, make the change, and see if ti works.

    running_loss += loss.item()

    model.eval()
    val_loss=0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
      for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        val_loss += loss.item() * inputs.size(0)
        tmp, preds = torch.max(outputs, 1)
        correct_val += (preds==labels).sum().item()
        total_val += labels.size(0)

    avg_val_loss = val_loss / total_val
    val_acc = correct_val / total_val

  scheduler.step(avg_val_loss)

  print(f"Epoch {epoch+1}/{num_epochs}")
  print(f"Val   Loss: {avg_val_loss:.4f}, Accuracy: {val_acc:.4f}")

  show_cuda_usage()
  print("Done!")




print(f"Epoch {epoch+1}, loss: {running_loss / len(trainloader)}")
# Out:
# Epoch 1 training....Epoch 1/200
# Val   Loss: 4.6009, Accuracy: 0.0191
# GPU Memory Used: 9001.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 2 training....Epoch 2/200
# Val   Loss: 4.5660, Accuracy: 0.0189
# GPU Memory Used: 9001.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 3 training....Epoch 3/200
# Val   Loss: 4.5087, Accuracy: 0.0230
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 4 training....Epoch 4/200
# Val   Loss: 4.4706, Accuracy: 0.0241
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 5 training....Epoch 5/200
# Val   Loss: 4.4105, Accuracy: 0.0297
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 6 training....Epoch 6/200
# Val   Loss: 4.3315, Accuracy: 0.0451
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 7 training....Epoch 7/200
# Val   Loss: 4.2653, Accuracy: 0.0489
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 8 training....Epoch 8/200
# Val   Loss: 4.2108, Accuracy: 0.0567
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 9 training....Epoch 9/200
# Val   Loss: 4.1623, Accuracy: 0.0612
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 10 training....Epoch 10/200
# Val   Loss: 4.1351, Accuracy: 0.0672
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 11 training....Epoch 11/200
# Val   Loss: 4.1059, Accuracy: 0.0683
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 12 training....Epoch 12/200
# Val   Loss: 4.0795, Accuracy: 0.0711
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 13 training....Epoch 13/200
# Val   Loss: 4.0666, Accuracy: 0.0791
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 14 training....Epoch 14/200
# Val   Loss: 4.0354, Accuracy: 0.0821
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 15 training....Epoch 15/200
# Val   Loss: 4.0099, Accuracy: 0.0836
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 16 training....Epoch 16/200
# Val   Loss: 4.0017, Accuracy: 0.0845
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 17 training....Epoch 17/200
# Val   Loss: 3.9834, Accuracy: 0.0904
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 57 training....Epoch 57/200
# Val   Loss: 3.4992, Accuracy: 0.1627
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 58 training....Epoch 58/200
# Val   Loss: 3.4695, Accuracy: 0.1691
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 59 training....Epoch 59/200
# Val   Loss: 3.4925, Accuracy: 0.1702
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 60 training....Epoch 60/200
# Val   Loss: 3.4787, Accuracy: 0.1660
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 61 training....Epoch 61/200
# Val   Loss: 3.4575, Accuracy: 0.1768
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 62 training....Epoch 62/200
# Val   Loss: 3.4498, Accuracy: 0.1718
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 63 training....Epoch 63/200
# Val   Loss: 3.4552, Accuracy: 0.1760
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 64 training....Epoch 64/200
# Val   Loss: 3.4325, Accuracy: 0.1744
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 65 training....Epoch 65/200
# Val   Loss: 3.4476, Accuracy: 0.1750
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 66 training....Epoch 66/200
# Val   Loss: 3.4261, Accuracy: 0.1796
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 67 training....Epoch 67/200
# Val   Loss: 3.4279, Accuracy: 0.1784
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 68 training....Epoch 68/200
# Val   Loss: 3.4272, Accuracy: 0.1823
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 69 training....Epoch 69/200
# Val   Loss: 3.4067, Accuracy: 0.1834
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 70 training....Epoch 70/200
# Val   Loss: 3.3865, Accuracy: 0.1867
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 71 training....Epoch 71/200
# Val   Loss: 3.3845, Accuracy: 0.1886
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 72 training....Epoch 72/200
# Val   Loss: 3.3787, Accuracy: 0.1899
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 73 training....Epoch 73/200
# Val   Loss: 3.3773, Accuracy: 0.1861
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 74 training....Epoch 74/200
# Val   Loss: 3.3687, Accuracy: 0.1913
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 75 training....Epoch 75/200
# Val   Loss: 3.3693, Accuracy: 0.1917
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 76 training....Epoch 76/200
# Val   Loss: 3.3843, Accuracy: 0.1863
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 77 training....Epoch 77/200
# Val   Loss: 3.3638, Accuracy: 0.1920
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 78 training....Epoch 78/200
# Val   Loss: 3.3297, Accuracy: 0.2009
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 79 training....Epoch 79/200
# Val   Loss: 3.3399, Accuracy: 0.1952
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 80 training....Epoch 80/200
# Val   Loss: 3.3679, Accuracy: 0.1918
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 81 training....Epoch 81/200
# Val   Loss: 3.3422, Accuracy: 0.1956
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 82 training....Epoch 82/200
# Val   Loss: 3.3250, Accuracy: 0.2026
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 83 training....Epoch 83/200
# Val   Loss: 3.3173, Accuracy: 0.1976
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 84 training....Epoch 84/200
# Val   Loss: 3.3000, Accuracy: 0.2048
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 85 training....Epoch 85/200
# Val   Loss: 3.2988, Accuracy: 0.2018
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 86 training....Epoch 86/200
# Val   Loss: 3.3016, Accuracy: 0.2086
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 87 training....Epoch 87/200
# Val   Loss: 3.2845, Accuracy: 0.2081
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 88 training....Epoch 88/200
# Val   Loss: 3.2868, Accuracy: 0.2051
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 89 training....Epoch 89/200
# Val   Loss: 3.2828, Accuracy: 0.2060
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 90 training....Epoch 90/200
# Val   Loss: 3.2743, Accuracy: 0.2067
# GPU Memory Used: 12991.88 MB
# GPU Memory Total: 15360.00 MB
# GPU Utilization: 0%
# Memory Utilization: 0%
# Done!
# Epoch 91 training....

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
  for images, labels in testloader:
    images, labels = images.to(device), labels.to(device)
    outputs = model(images)
    temp, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

print(f"Test Accuracy: {100 * correct / total:.2f}%")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

folder_path = '/content/drive/MyDrive/artificialintelligence/Colab Notebooks/Models'


# Make sure the nested directory exists
save_path = os.path.join(folder_path, 'model.pth')

# Example: Save model's state_dict
torch.save(model.state_dict(), save_path)
